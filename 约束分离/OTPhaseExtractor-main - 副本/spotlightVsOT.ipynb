# %%
from extractors import SpotlightSolution1d, OptimalTransport1d
from utils.coordinates import RadialCoordinates
from utils.make_data import make_gauss, make_donut, make_disk

import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from extractors import SpotlightSolution1d, OptimalTransport1d
#       2 from utils.coordinates import RadialCoordinates
#       3 from utils.make_data import make_gauss, make_donut, make_disk
#
# File d:\6.2谈话资料\OTPhaseExtractor-main\extractors\__init__.py:2
#       1 from extractors.GSphase import GerchbergSaxton2d
# ----> 2 from extractors.OTphase import OptimalTransport1d, FlattenOptimalTransport2d
#       3 from extractors.SPphase import SpotlightSolution1d
#       4 from extractors.COTphase import ContinuousOptimalTransport2d
#
# File d:\6.2谈话资料\OTPhaseExtractor-main\extractors\OTphase.py:1
# ----> 1 import ot
#       2 import ot.plot
#       3 import matplotlib.pyplot as plt
#
# File d:\python1\Lib\site-packages\ot\__init__.py:20
#       1 """
#       2 .. warning::
#       3     The list of automatically imported sub-modules is as follows:
#    (...)     11     - :any:`ot.plot` : depends on :code:`matplotlib`
#      12 """
#      14 # Author: Remi Flamary <remi.flamary@unice.fr>
#      15 #         Nicolas Courty <ncourty@irisa.fr>
#      16 #
#      17 # License: MIT License
#      18
#      19 # All submodules and packages
# ---> 20 from . import lp
#      21 from . import bregman
#      22 from . import optim
#
# File d:\python1\Lib\site-packages\ot\lp\__init__.py:11
#       2 """
#       3 Solvers for the original linear program OT problem.
#       4
#       5 """
#       7 # Author: Remi Flamary <remi.flamary@unice.fr>
#       8 #
#       9 # License: MIT License
# ---> 11 from .dmmot import dmmot_monge_1dgrid_loss, dmmot_monge_1dgrid_optimize
#      12 from ._network_simplex import emd, emd2
#      13 from ._barycenter_solvers import (
#      14     barycenter,
#      15     free_support_barycenter,
#    (...)     19     NorthWestMMGluing,
#      20 )
#
# File d:\python1\Lib\site-packages\ot\lp\dmmot.py:12
#       6 # Author: Ronak Mehta <ronakrm@cs.wisc.edu>
#       7 #         Xizheng Yu <xyu354@wisc.edu>
#       8 #
#       9 # License: MIT License
#      11 import numpy as np
# ---> 12 from ..backend import get_backend
#      15 def dist_monge_max_min(i):
#      16     r"""
#      17     A tensor :math:c is Monge if for all valid :math:i_1, \ldots i_d and
#      18     :math:j_1, \ldots, j_d,
#    (...)     54         Workshop on Discrete Algorithms.
#      55     """
#
# File d:\python1\Lib\site-packages\ot\backend.py:107
#     105 if not os.environ.get(DISABLE_TORCH_KEY, False):
#     106     try:
# --> 107         import torch
#     109         torch_type = torch.Tensor
#     110     except ImportError:
#
# File d:\python1\Lib\site-packages\torch\__init__.py:2838
#    2835         import torch.distributed._meta_registrations as coll_meta_registrations
#    2837         del coll_meta_registrations
# -> 2838     from torch import _meta_registrations
#    2840 # Enable CUDA Sanitizer
#    2841 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File d:\python1\Lib\site-packages\torch\_meta_registrations.py:12
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#      15     global_decomposition_table,
#      16     meta_table,
#      17 )
#      18 from torch._ops import OpOverload
#      19 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File d:\python1\Lib\site-packages\torch\_decomp\__init__.py:288
#     286 # populate the table
#     287 import torch._decomp.decompositions
# --> 288 import torch._refs
#     291 def core_aten_decompositions() -> "CustomDecompTable":
#     292     from torch.export.exported_program import default_decompositions
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1190, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# define coordinate system
n = 1024
coordinates = RadialCoordinates(1024)
r = coordinates.r

# %%
# create test data
sigma_a = 10
sigma_b = 8
a = make_gauss(r, sigma_a) * r
b = make_gauss(r, sigma_b) * r

# compute phase
OTmodel = OptimalTransport1d(method='emd', plot_plan=True)
Spotlight = SpotlightSolution1d()

# compute phase derivatice
dphi_dr_ot = OTmodel(a, b, r)
dphi_dr_spot = Spotlight(a, b, r)
plt.figure(figsize=(10, 10))
plt.plot(r, dphi_dr_ot, label='Optimal Transport soluiton')
plt.plot(r, dphi_dr_spot, label='Spotlight Numerical soluiton')
plt.plot(r, r*sigma_b/sigma_a, label='Spotlight Analytical soluiton')
plt.legend()
plt.show()

# %%
# create test data
R = 10
sigma_a = 5
sigma_b = 5
a = make_gauss(r, sigma_a) * r
b = make_disk(r, R, sigma_b) * r

# compute phase
OTmodel = OptimalTransport1d(method='emd', plot_plan=True)
Spotlight = SpotlightSolution1d()

# compute phase derivatice
dphi_dr_ot = OTmodel(a, b, r)
dphi_dr_spot = Spotlight(a, b, r)
plt.figure(figsize=(10, 10))
plt.plot(r, dphi_dr_ot, label='Optimal Transport soluiton')
plt.plot(r, dphi_dr_spot, label='Spotlight Numerical soluiton')
p_inv = lambda u: np.sqrt((R + sigma_b)**2 - 4 * sigma_b * R * np.exp(-r**2/sigma_a**2))
plt.plot(r, p_inv(r), label='Spotlight Theory solution')
plt.legend()
plt.show()

# %%
# create test data
R = 10
sigma_a = 5
sigma_b = 3
a = make_gauss(r, sigma_a) * r
b = make_donut(r, R, sigma_b) * r

# compute phase
OTmodel = OptimalTransport1d(method='emd', plot_plan=True)
Spotlight = SpotlightSolution1d()

# compute phase derivatice
dphi_dr_ot = OTmodel(a, b, r)
dphi_dr_spot = Spotlight(a, b, r)
plt.figure(figsize=(10, 10))
plt.plot(r, dphi_dr_ot, label='Optimal Transport soluiton')
plt.plot(r, dphi_dr_spot, label='Spotlight Numerical soluiton')
#plt.plot(r, sigma_b*np.sqrt(np.tan(np.pi/2 - np.pi*np.exp(-r**2/sigma_a**2)+(R/sigma_b)**2)), label='Spotlight Theoretical solution') ## wrong
plt.legend()
plt.show()
